# %%
import numpy as np
import pandas as pd

file_path = '/content/RS_246.csv'

road_data = pd.read_csv(file_path)
road_data.head()
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0  Countries, territories and areas       Year
# 1                           Albania       2016
# 2                           Andorra       2013
# 3                            Angola       2016
# 4               Antigua and Barbuda       2016
#
#   Distribution of road traffic deaths by type of road user (%)  \
# 0           Drivers/passengers of 4-wheeled vehicles
# 1                                               39.4
# 2                                                NaN
# 3                                               59.5
# 4                                               62.5
#
#   Distribution of road traffic deaths by type of road user (%).1  \
# 0   Drivers/passengers of motorized 2- or 3-wheelers
# 1                                               11.9
# 2                                               50.0
# 3                                                NaN
# 4                                                0.0
#
# ...

# %%
#Check the missing datas
road_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 7 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Unnamed: 0                                                      149 non-null    object
#  1   Unnamed: 1                                                      149 non-null    object
#  2   Distribution of road traffic deaths by type of road user (%)    135 non-null    object
#  3   Distribution of road traffic deaths by type of road user (%).1  129 non-null    object
#  4   Distribution of road traffic deaths by type of road user (%).2  127 non-null    object
#  5   Distribution of road traffic deaths by type of road user (%).3  137 non-null    object
#  6   Distribution of road traffic deaths by type of road user (%).4  132 non-null    object
# dtypes: object(7)
# memory usage: 8.3+ KB

# %%
road_data.isnull().sum()
# Out:
# Unnamed: 0                                                         0
# Unnamed: 1                                                         0
# Distribution of road traffic deaths by type of road user (%)      14
# Distribution of road traffic deaths by type of road user (%).1    20
# Distribution of road traffic deaths by type of road user (%).2    22
# Distribution of road traffic deaths by type of road user (%).3    12
# Distribution of road traffic deaths by type of road user (%).4    17
# dtype: int64

# %%
np.mean(road_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Series([], dtype: float64)

# %%
road_data.drop([0], axis = 0, inplace = True)
road_data
# Out:
#                    Unnamed: 0 Unnamed: 1  \
# 1                     Albania       2016
# 2                     Andorra       2013
# 3                      Angola       2016
# 4         Antigua and Barbuda       2016
# 5                   Argentina       2016
# ..                        ...        ...
# 144  United States of America       2016
# 145                   Uruguay       2016
# 146                  Viet Nam       2016
# 147                    Zambia       2013
# 148                  Zimbabwe       2016
#
#     Distribution of road traffic deaths by type of road user (%)  \
# 1                                                 39.4
# 2                                                  NaN
# 3                                                 59.5
# 4                                                 62.5
# 5                                                 47.2
# ..                                                 ...
# 144                                               30.7
# ...

# %%
updated_df = road_data
updated_df['Drivers/passengers of 4-wheeled vehicles']=updated_df['Drivers/passengers of 4-wheeled vehicles'].fillna(updated_df['Drivers/passengers of 4-wheeled vehicles'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Drivers/passengers of 4-wheeled vehicles'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
road_data.fillna(road_data.mean(), inplace = True)
road_data
# Out:
# <ipython-input-42-f50ca0af3f6e>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   road_data.fillna(road_data.mean(), inplace = True)
#                            Unnamed: 0 Unnamed: 1  \
# 0    Countries, territories and areas       Year
# 1                             Albania       2016
# 2                             Andorra       2013
# 3                              Angola       2016
# 4                 Antigua and Barbuda       2016
# ..                                ...        ...
# 144          United States of America       2016
# 145                           Uruguay       2016
# 146                          Viet Nam       2016
# 147                            Zambia       2013
# 148                          Zimbabwe       2016
#
# ...

# %%
#road_data.fillna(road_data.select_dtypes(np.number).mean(), inplace = True)
road_data.head()
# Out:
#                          Unnamed: 0 Unnamed: 1  \
# 0  Countries, territories and areas       Year
# 1                           Albania       2016
# 2                           Andorra       2013
# 3                            Angola       2016
# 4               Antigua and Barbuda       2016
#
#   Distribution of road traffic deaths by type of road user (%)  \
# 0           Drivers/passengers of 4-wheeled vehicles
# 1                                               39.4
# 2                                                NaN
# 3                                               59.5
# 4                                               62.5
#
#   Distribution of road traffic deaths by type of road user (%).1  \
# 0   Drivers/passengers of motorized 2- or 3-wheelers
# 1                                               11.9
# 2                                               50.0
# 3                                                NaN
# 4                                                0.0
#
# ...

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 1 to 148
# Data columns (total 7 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Unnamed: 0                                                      148 non-null    object
#  1   Unnamed: 1                                                      148 non-null    object
#  2   Distribution of road traffic deaths by type of road user (%)    134 non-null    object
#  3   Distribution of road traffic deaths by type of road user (%).1  128 non-null    object
#  4   Distribution of road traffic deaths by type of road user (%).2  126 non-null    object
#  5   Distribution of road traffic deaths by type of road user (%).3  136 non-null    object
#  6   Distribution of road traffic deaths by type of road user (%).4  131 non-null    object
# dtypes: object(7)
# memory usage: 8.2+ KB

# %%
updated_df = road_data
updated_df['Distribution of road traffic deaths by type of road user (%)']=updated_df['Distribution of road traffic deaths by type of road user (%).1'].fillna(updated_df['Distribution of road traffic deaths by type of road user (%).1'].mean())
updated_df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-f266c0958b5d> in <cell line: 2>()
#       1 updated_df = road_data
# ----> 2 updated_df['Distribution of road traffic deaths by type of road user (%).1']=updated_df['Distribution of road traffic deaths by type of road user (%).1'].fillna(updated_df['Distribution of road traffic deaths by type of road user (%).1'].mean())
#       3 updated_df.info()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
# ...

# %%
#value_1 = {'Distribution of road traffic deaths by type of road user (%)':148}

updated_df = road_data.fillna(road_data['Distribution of road traffic deaths by type of road user (%)'].mean(numeric_only=True), inplace = True)
updated_df
# Out:
# <ipython-input-49-0df78174dfd9>:3: FutureWarning: Calling Series.mean with numeric_only=True and dtype object will raise a TypeError in the future
#   updated_df = road_data.fillna(road_data['Distribution of road traffic deaths by type of road user (%)'].mean(numeric_only=True), inplace = True)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-49-0df78174dfd9> in <cell line: 3>()
#       1 #value_1 = {'Distribution of road traffic deaths by type of road user (%)':148}
#       2
# ----> 3 updated_df = road_data.fillna(road_data['Distribution of road traffic deaths by type of road user (%)'].mean(numeric_only=True), inplace = True)
#       4 updated_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# ...

# %%
road_data.mean()
# Out:
# <ipython-input-48-c3a1fcaf6caf>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   road_data.mean()
# Series([], dtype: float64)

# %%
road_data.fillna(0.)
# Out:
#                            Unnamed: 0 Unnamed: 1  \
# 0    Countries, territories and areas       Year
# 1                             Albania       2016
# 2                             Andorra       2013
# 3                              Angola       2016
# 4                 Antigua and Barbuda       2016
# ..                                ...        ...
# 144          United States of America       2016
# 145                           Uruguay       2016
# 146                          Viet Nam       2016
# 147                            Zambia       2013
# 148                          Zimbabwe       2016
#
#     Distribution of road traffic deaths by type of road user (%)  \
# 0             Drivers/passengers of 4-wheeled vehicles
# 1                                                 39.4
# 2                                                  0.0
# 3                                                 59.5
# 4                                                 62.5
# ...

# %%
road_data.mean()
# Out:
# <ipython-input-51-c3a1fcaf6caf>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   road_data.mean()
# Series([], dtype: float64)

# %%
road_data.drop([], axis=1, inplace=True)
road_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-77c991d5939a> in <cell line: 1>()
# ----> 1 road_data.drop([0], axis=1, inplace=True)
#       2 road_data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
column_mean = road_data['Distribution of road traffic deaths by type of road user (%)'].mean()
road_data['Distribution of road traffic deaths by type of road user (%)'].fillna(column_mean, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-f74bdc0d88b1> in <cell line: 1>()
# ----> 1 column_mean = road_data['Distribution of road traffic deaths by type of road user (%)'].mean()
#       2 road_data['Distribution of road traffic deaths by type of road user (%)'].fillna(column_mean, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
# ...

# %%
road_data
# Out:
#                            Unnamed: 0 Unnamed: 1  \
# 0    Countries, territories and areas       Year
# 1                             Albania       2016
# 2                             Andorra       2013
# 3                              Angola       2016
# 4                 Antigua and Barbuda       2016
# ..                                ...        ...
# 144          United States of America       2016
# 145                           Uruguay       2016
# 146                          Viet Nam       2016
# 147                            Zambia       2013
# 148                          Zimbabwe       2016
#
#     Distribution of road traffic deaths by type of road user (%)  \
# 0             Drivers/passengers of 4-wheeled vehicles
# 1                                                 39.4
# 2                                                  NaN
# 3                                                 59.5
# 4                                                 62.5
# ...

# %%
road_data.drop(road_data.index[0], axis = 0, inplace=True)
road_data
# Out:
#                    Unnamed: 0 Unnamed: 1  \
# 1                     Albania       2016
# 2                     Andorra       2013
# 3                      Angola       2016
# 4         Antigua and Barbuda       2016
# 5                   Argentina       2016
# ..                        ...        ...
# 144  United States of America       2016
# 145                   Uruguay       2016
# 146                  Viet Nam       2016
# 147                    Zambia       2013
# 148                  Zimbabwe       2016
#
#     Distribution of road traffic deaths by type of road user (%)  \
# 1                                                 39.4
# 2                                                  NaN
# 3                                                 59.5
# 4                                                 62.5
# 5                                                 47.2
# ..                                                 ...
# 144                                               30.7
# ...

# %%
column_mean = road_data['Distribution of road traffic deaths by type of road user (%).3'].mean()
road_data['Distribution of road traffic deaths by type of road user (%).3'].fillna(column_mean, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-3719340a3535> in <cell line: 1>()
# ----> 1 column_mean = road_data['Distribution of road traffic deaths by type of road user (%).3'].mean()
#       2 road_data['Distribution of road traffic deaths by type of road user (%).3'].fillna(column_mean, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11845             **kwargs,
#   11846         ):
# > 11847             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11848
#   11849         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11399         **kwargs,
#   11400     ) -> Series | float:
# > 11401         return self._stat_function(
# ...

# %%
road_data
# Out:
#                    Unnamed: 0 Unnamed: 1  \
# 1                     Albania       2016
# 2                     Andorra       2013
# 3                      Angola       2016
# 4         Antigua and Barbuda       2016
# 5                   Argentina       2016
# ..                        ...        ...
# 144  United States of America       2016
# 145                   Uruguay       2016
# 146                  Viet Nam       2016
# 147                    Zambia       2013
# 148                  Zimbabwe       2016
#
#     Distribution of road traffic deaths by type of road user (%)  \
# 1                                                 39.4
# 2                                                  NaN
# 3                                                 59.5
# 4                                                 62.5
# 5                                                 47.2
# ..                                                 ...
# 144                                               30.7
# ...

# %%
road_data['Distribution of road traffic deaths by type of road user (%)']=pd.to_numeric(road_data['Distribution of road traffic deaths by type of road user (%)'], errors = 'coerce').astype(int)
road_data
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-68-e20c6c595986> in <cell line: 1>()
# ----> 1 road_data['Distribution of road traffic deaths by type of road user (%)']=pd.to_numeric(road_data['Distribution of road traffic deaths by type of road user (%)'], errors = 'coerce').astype(int)
#       2 road_data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
# ...

# %%
road_data[40:50]
# Out:
#    Unnamed: 0 Unnamed: 1  \
# 41    Estonia       2016
# 42   Eswatini       2016
# 43   Eswatini       2013
# 44   Ethiopia       2016
# 45       Fiji       2016
# 46    Finland       2016
# 47     France       2016
# 48    Georgia       2016
# 49    Germany       2016
# 50      Ghana       2016
#
#    Distribution of road traffic deaths by type of road user (%)  \
# 41                                               52.1
# 42                                               53.7
# 43                                               62.4
# 44                                                0.0
# 45                                              63.3h
# 46                                               64.7
# 47                                               54.4
# 48                                               44.9
# 49                                               47.8
# 50                                               12.0
#
# ...
