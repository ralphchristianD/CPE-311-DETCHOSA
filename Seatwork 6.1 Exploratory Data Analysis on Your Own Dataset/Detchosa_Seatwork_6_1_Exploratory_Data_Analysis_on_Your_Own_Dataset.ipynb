# %%
import numpy as np
import pandas as pd

file_path = '/content/RS_246 (1).csv'

df = pd.read_csv(file_path)
df
# Out:
#                            Unnamed: 0 Unnamed: 1  \
# 0    Countries, territories and areas       Year
# 1                             Albania       2016
# 2                             Andorra       2013
# 3                              Angola       2016
# 4                 Antigua and Barbuda       2016
# ..                                ...        ...
# 144          United States of America       2016
# 145                           Uruguay       2016
# 146                          Viet Nam       2016
# 147                            Zambia       2013
# 148                          Zimbabwe       2016
#
#     Distribution of road traffic deaths by type of road user (%)  \
# 0             Drivers/passengers of 4-wheeled vehicles
# 1                                                 39.4
# 2                                                  NaN
# 3                                                 59.5
# 4                                                 62.5
# ..                                                 ...
# 144                                               30.7
# 145                                                NaN
# 146                                               52.2
# 147                                               48.4
# 148                                                NaN
#
#     Distribution of road traffic deaths by type of road user (%).1  \
# 0     Drivers/passengers of motorized 2- or 3-wheelers
# 1                                                 11.9
# 2                                                 50.0
# 3                                                  NaN
# 4                                                  0.0
# ..                                                 ...
# 144                                               14.2
# 145                                               45.7
# 146                                                NaN
# 147                                                NaN
# 148                                               10.2
#
#     Distribution of road traffic deaths by type of road user (%).2  \
# 0                                             Cyclists
# 1                                                  7.8
# 2                                                  NaN
# 3                                                  NaN
# 4                                                 12.5
# ..                                                 ...
# 144                                                2.3
# 145                                                7.0
# 146                                                NaN
# 147                                               11.6
# 148                                               12.2
#
#     Distribution of road traffic deaths by type of road user (%).3  \
# 0                                          Pedestrians
# 1                                                 38.7
# 2                                                 50.0
# 3                                                 40.5
# 4                                                 25.0
# ..                                                 ...
# 144                                               15.3
# 145                                               16.6
# 146                                                NaN
# 147                                               36.4
# 148                                               13.7
#
#     Distribution of road traffic deaths by type of road user (%).4
# 0                         Other/unspecified road users
# 1                                                  2.2
# 2                                                  NaN
# 3                                                  0.0
# 4                                                  0.0
# ..                                                 ...
# 144                                                4.2
# 145                                                0.0
# 146                                                NaN
# 147                                                NaN
# 148                                               37.2
#
# [149 rows x 7 columns]

# %%
# Reformat the labels
df.columns = ['Country', 'Year', '4-wheeled', '2 or 3-wheeled', 'Cyclists',
           'Pedestrians', 'Others']
df.drop([0], axis=0, inplace=True)
df.drop('Others', axis=1, inplace=True)
df
# Out:
#                       Country   Year 4-wheeled 2 or 3-wheeled Cyclists  \
# 1                     Albania   2016      39.4           11.9      7.8
# 2                     Andorra   2013       NaN           50.0      NaN
# 3                      Angola   2016      59.5            NaN      NaN
# 4         Antigua and Barbuda   2016      62.5            0.0     12.5
# 5                   Argentina   2016      47.2           22.2      2.4
# ..                        ...    ...       ...            ...      ...
# 144  United States of America   2016      30.7           14.2      2.3
# 145                   Uruguay   2016       NaN           45.7      7.0
# 146                  Viet Nam   2016      52.2            NaN      NaN
# 147                    Zambia   2013      48.4            NaN     11.6
# 148                  Zimbabwe   2016       NaN           10.2     12.2
#
#     Pedestrians
# 1          38.7
# 2          50.0
# 3          40.5
# 4          25.0
# 5           8.2
# ..          ...
# 144        15.3
# 145        16.6
# 146         NaN
# 147        36.4
# 148        13.7
#
# [148 rows x 6 columns]

# %%
df[65:80]
# Out:
#              Country   Year 4-wheeled 2 or 3-wheeled Cyclists Pedestrians
# 66        Kazakhstan   2016      59.8            4.3      1.7        30.9
# 67             Kenya   2016     36.4h           24.2      2.4        37.0
# 68          Kiribati   2016      40.0           20.0      0.0        40.0
# 69        Kyrgyzstan   2016      27.6            2.1      0.2        40.0
# 70            Latvia   2016      44.9           12.0      4.4        34.8
# 71           Lebanon   2016     42.4h           20.7      NaN        37.0
# 72             Libya   2016      75.0            1.9      2.3        20.8
# 73         Lithuania   2016     46.4h            5.7      8.9        38.0
# 74        Luxembourg   2016      62.5            9.4      3.1        25.0
# 75        Madagascar   2016     52.9h            NaN      NaN        47.1
# 76            Malawi   2016      31.1            3.2     16.0        49.6
# 77          Maldives   2016       0.0           75.0      0.0        25.0
# 78              Mali   2016      27.9           42.3      2.4        11.5
# 79             Malta   2016      18.2           40.9      4.5        27.3
# 80  Marshall Islands   2013      33.3           66.7      NaN         NaN

# %%
# function for removing the non numeric in the column
def remove_non_numeric(text):
    if isinstance(text, str):
        return ''.join(char for char in text if char.isdigit() or char == '.')
    else:
        return text

df['4-wheeled'] = df['4-wheeled'].apply(remove_non_numeric)
df
# Out:
#                       Country   Year 4-wheeled 2 or 3-wheeled Cyclists  \
# 1                     Albania   2016      39.4           11.9      7.8
# 2                     Andorra   2013       NaN           50.0      NaN
# 3                      Angola   2016      59.5            NaN      NaN
# 4         Antigua and Barbuda   2016      62.5            0.0     12.5
# 5                   Argentina   2016      47.2           22.2      2.4
# ..                        ...    ...       ...            ...      ...
# 144  United States of America   2016      30.7           14.2      2.3
# 145                   Uruguay   2016       NaN           45.7      7.0
# 146                  Viet Nam   2016      52.2            NaN      NaN
# 147                    Zambia   2013      48.4            NaN     11.6
# 148                  Zimbabwe   2016       NaN           10.2     12.2
#
#     Pedestrians
# 1          38.7
# 2          50.0
# 3          40.5
# 4          25.0
# 5           8.2
# ..          ...
# 144        15.3
# 145        16.6
# 146         NaN
# 147        36.4
# 148        13.7
#
# [148 rows x 6 columns]

# %%
df[65:80]
# Out:
#              Country   Year 4-wheeled 2 or 3-wheeled Cyclists Pedestrians
# 66        Kazakhstan   2016      59.8            4.3      1.7        30.9
# 67             Kenya   2016      36.4           24.2      2.4        37.0
# 68          Kiribati   2016      40.0           20.0      0.0        40.0
# 69        Kyrgyzstan   2016      27.6            2.1      0.2        40.0
# 70            Latvia   2016      44.9           12.0      4.4        34.8
# 71           Lebanon   2016      42.4           20.7      NaN        37.0
# 72             Libya   2016      75.0            1.9      2.3        20.8
# 73         Lithuania   2016      46.4            5.7      8.9        38.0
# 74        Luxembourg   2016      62.5            9.4      3.1        25.0
# 75        Madagascar   2016      52.9            NaN      NaN        47.1
# 76            Malawi   2016      31.1            3.2     16.0        49.6
# 77          Maldives   2016       0.0           75.0      0.0        25.0
# 78              Mali   2016      27.9           42.3      2.4        11.5
# 79             Malta   2016      18.2           40.9      4.5        27.3
# 80  Marshall Islands   2013      33.3           66.7      NaN         NaN

# %%
df.isnull()
# Out:
#      Country   Year  4-wheeled  2 or 3-wheeled  Cyclists  Pedestrians
# 1      False  False      False           False     False        False
# 2      False  False       True           False      True        False
# 3      False  False      False            True      True        False
# 4      False  False      False           False     False        False
# 5      False  False      False           False     False        False
# ..       ...    ...        ...             ...       ...          ...
# 144    False  False      False           False     False        False
# 145    False  False       True           False     False        False
# 146    False  False      False            True      True         True
# 147    False  False      False            True     False        False
# 148    False  False       True           False     False        False
#
# [148 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Country            0
# Year               0
# 4-wheeled         14
# 2 or 3-wheeled    20
# Cyclists          22
# Pedestrians       12
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 68

# %%
df2 = df.fillna(value = 0)

# %%
# data frame for not removing the NaN or null values
columns = ['4-wheeled', '2 or 3-wheeled', 'Cyclists', 'Pedestrians']

for column in columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')
    mean_value = df[column].mean()
    print(f"The Mean of {column}: {mean_value}")
# Out:
# The Mean of 4-wheeled: 39.435074626865664
# The Mean of 2 or 3-wheeled: 20.76796875
# The Mean of Cyclists: 5.58968253968254
# The Mean of Pedestrians: 27.116176470588236

# %%
df
# Out:
#                       Country   Year  4-wheeled  2 or 3-wheeled  Cyclists  \
# 1                     Albania   2016       39.4            11.9       7.8
# 2                     Andorra   2013        NaN            50.0       NaN
# 3                      Angola   2016       59.5             NaN       NaN
# 4         Antigua and Barbuda   2016       62.5             0.0      12.5
# 5                   Argentina   2016       47.2            22.2       2.4
# ..                        ...    ...        ...             ...       ...
# 144  United States of America   2016       30.7            14.2       2.3
# 145                   Uruguay   2016        NaN            45.7       7.0
# 146                  Viet Nam   2016       52.2             NaN       NaN
# 147                    Zambia   2013       48.4             NaN      11.6
# 148                  Zimbabwe   2016        NaN            10.2      12.2
#
#      Pedestrians
# 1           38.7
# 2           50.0
# 3           40.5
# 4           25.0
# 5            8.2
# ..           ...
# 144         15.3
# 145         16.6
# 146          NaN
# 147         36.4
# 148         13.7
#
# [148 rows x 6 columns]

# %%
# Data frame for replacing the NaN with zeros of each columns
columns = ['4-wheeled', '2 or 3-wheeled', 'Cyclists', 'Pedestrians']

for column in columns:
    df2[column] = pd.to_numeric(df2[column], errors='coerce')
    mean_value = df2[column].mean()
    print(f"The Mean of {column}: {mean_value}")
# Out:
# The Mean of 4-wheeled: 35.70472972972973
# The Mean of 2 or 3-wheeled: 17.96148648648649
# The Mean of Cyclists: 4.758783783783784
# The Mean of Pedestrians: 24.91756756756757

# %%
df2
# Out:
#                       Country   Year  4-wheeled  2 or 3-wheeled  Cyclists  \
# 1                     Albania   2016       39.4            11.9       7.8
# 2                     Andorra   2013        0.0            50.0       0.0
# 3                      Angola   2016       59.5             0.0       0.0
# 4         Antigua and Barbuda   2016       62.5             0.0      12.5
# 5                   Argentina   2016       47.2            22.2       2.4
# ..                        ...    ...        ...             ...       ...
# 144  United States of America   2016       30.7            14.2       2.3
# 145                   Uruguay   2016        0.0            45.7       7.0
# 146                  Viet Nam   2016       52.2             0.0       0.0
# 147                    Zambia   2013       48.4             0.0      11.6
# 148                  Zimbabwe   2016        0.0            10.2      12.2
#
#      Pedestrians
# 1           38.7
# 2           50.0
# 3           40.5
# 4           25.0
# 5            8.2
# ..           ...
# 144         15.3
# 145         16.6
# 146          0.0
# 147         36.4
# 148         13.7
#
# [148 rows x 6 columns]

# %%
# Median
columns = ['4-wheeled', '2 or 3-wheeled', 'Cyclists', 'Pedestrians']

for column in columns:
    df2[column] = pd.to_numeric(df2[column], errors='coerce')
    median_value = df2[column].median()
    print(f"The Median of {column}: {median_value}")
# Out:
# The Median of 4-wheeled: 40.15
# The Median of 2 or 3-wheeled: 13.2
# The Median of Cyclists: 2.6
# The Median of Pedestrians: 24.75

# %%
# Variance
columns = ['4-wheeled', '2 or 3-wheeled', 'Cyclists', 'Pedestrians']

for column in columns:
    df2[column] = pd.to_numeric(df2[column], errors='coerce')
    variance_value = df2[column].var()
    print(f"The sample variance of {column}: {variance_value}")
# Out:
# The sample variance of 4-wheeled: 455.95800468836177
# The sample variance of 2 or 3-wheeled: 377.0659215848502
# The sample variance of Cyclists: 43.28352776245634
# The sample variance of Pedestrians: 221.58281853281855

# %%
# Standard Deviation
columns = ['4-wheeled', '2 or 3-wheeled', 'Cyclists', 'Pedestrians']

for column in columns:
    df2[column] = pd.to_numeric(df2[column], errors='coerce')
    standev_value = df2[column].std()
    print(f"The Standard Deviation of {column}: {standev_value}")
# Out:
# The Standard Deviation of 4-wheeled: 21.353173176096377
# The Standard Deviation of 2 or 3-wheeled: 19.41818533192147
# The Standard Deviation of Cyclists: 6.579021793736234
# The Standard Deviation of Pedestrians: 14.885658149131954
